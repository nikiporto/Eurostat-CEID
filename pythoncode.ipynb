# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mysql.connector

# %% [markdown]
# # Διαβάζω το csv αρχείο με τη χρήση της βιβλιοθήκης pandas

# %%
df=pd.read_csv("tour_occ_ninat_1_Data.csv")

# %% [markdown]
# # Nights spent at holiday accomondations
# Διάλαξα την Ελλάδα και το Βέλγιο και διαμόρφωσα τα dataframes έτσι ώστε να κρατήσουμε τα δεδομένα που θέλουμε μόνο

# %%
nightsg= df[  df["TIME"] >=2016 ]
nightsg= nightsg[ nightsg["TIME"] <=2019 ]
nightsg=nightsg.sort_values(by=['TIME'])
nightsg=nightsg.loc[nightsg['GEO'] == 'Greece']
nightsg=nightsg.loc[nightsg['C_RESID'] == 'Total']
nightsg=nightsg.loc[nightsg['UNIT']== 'Number']

indices=[18875,21875,24875,27875]
nightsg=nightsg.loc[indices]

nightsg['Value'] =nightsg['Value'].replace(',','', regex=True)
nightsg['Value']=nightsg['Value'].astype(int)
nightsg
# Out:
#        TIME     GEO C_RESID    UNIT  \
# 18875  2016  Greece   Total  Number
# 21875  2017  Greece   Total  Number
# 24875  2018  Greece   Total  Number
# 27875  2019  Greece   Total  Number
#
#                                                  NACE_R2      Value  \
# 18875  Hotels; holiday and other short-stay accommoda...  110020042
# 21875  Hotels; holiday and other short-stay accommoda...  119009014
# 24875  Hotels; holiday and other short-stay accommoda...  123087178
# 27875  Hotels; holiday and other short-stay accommoda...  143594467
#
#       Flag and Footnotes
# 18875                NaN
# 21875                NaN
# 24875                NaN
# 27875                NaN

# %% [markdown]
# # Δημιουργία των pie charts κατευθείαν από το dataframe

# %%
print('Nights spent at holiday accomondations in Greece for the years 2016-2017-2018-2019')
plt.pie(nightsg['Value'],labels=nightsg['TIME'],autopct='%1.1f%%')
plt.legend(title = "Four Years:")
plt.show()
# Out:
# Nights spent at holiday accomondations in Greece for the years 2016-2017-2018-2019

# %%
nightsb= df[df["TIME"] >=2016 ]
nightsb= nightsb[ nightsb["TIME"] <=2019 ]
nightsb=nightsb.sort_values(by=['TIME'])
nightsb=nightsb.loc[nightsb['GEO'] == 'Belgium']
nightsb=nightsb.loc[nightsb['C_RESID'] == 'Total']
nightsb=nightsb.loc[nightsb['UNIT']== 'Number']

indices=[18350,21350,24350,27350]
nightsb=nightsb.loc[indices]
nightsb
# Out:
#        TIME      GEO C_RESID    UNIT  \
# 18350  2016  Belgium   Total  Number
# 21350  2017  Belgium   Total  Number
# 24350  2018  Belgium   Total  Number
# 27350  2019  Belgium   Total  Number
#
#                                                  NACE_R2       Value  \
# 18350  Hotels; holiday and other short-stay accommoda...  36,855,214
# 21350  Hotels; holiday and other short-stay accommoda...  38,677,308
# 24350  Hotels; holiday and other short-stay accommoda...  41,320,284
# 27350  Hotels; holiday and other short-stay accommoda...  42,512,847
#
#       Flag and Footnotes
# 18350                NaN
# 21350                NaN
# 24350                NaN
# 27350                NaN

# %%
nightsb['Value'] =nightsb['Value'].replace(',','', regex=True)
nightsb['Value']=nightsb['Value'].astype(int)

# %%
print('Nights spent at holiday accomondations in Belgium for the years 2016-2017-2018-2019')
plt.pie(nightsb['Value'],labels=nightsb['TIME'],autopct='%1.1f%%')
plt.legend(title = "Four Years:")
plt.show()
# Out:
# Nights spent at holiday accomondations in Belgium for the years 2016-2017-2018-2019

# %% [markdown]
# # Nights spent by non-residents at tourist accommodation establishments
# Παρόμοια με παραπάνω απλώς σε αυτή την περίπτωση έχουμε ένα ακόμα κριτήριο

# %%
nightsgnr= df[  df["TIME"] >=2016 ]
nightsgnr= nightsgnr[ nightsgnr["TIME"] <=2019 ]
nightsgnr=nightsgnr.sort_values(by=['TIME'])
nightsgnr=nightsgnr.loc[nightsgnr['GEO'] == 'Greece']
nightsgnr=nightsgnr.loc[nightsgnr['C_RESID'] == 'Foreign country']
nightsgnr=nightsgnr.loc[nightsgnr['UNIT']== 'Number']
indices=[18825,21825,24825,27825]
nightsgnr=nightsgnr.loc[indices]

nightsgnr
# Out:
#        TIME     GEO          C_RESID    UNIT  \
# 18825  2016  Greece  Foreign country  Number
# 21825  2017  Greece  Foreign country  Number
# 24825  2018  Greece  Foreign country  Number
# 27825  2019  Greece  Foreign country  Number
#
#                                                  NACE_R2        Value  \
# 18825  Hotels; holiday and other short-stay accommoda...   87,912,850
# 21825  Hotels; holiday and other short-stay accommoda...   97,034,421
# 24825  Hotels; holiday and other short-stay accommoda...  102,571,241
# 27825  Hotels; holiday and other short-stay accommoda...  119,971,390
#
#       Flag and Footnotes
# 18825                NaN
# 21825                NaN
# 24825                NaN
# 27825                NaN

# %%
nightsgnr['Value'] =nightsgnr['Value'].replace(',','', regex=True)
nightsgnr['Value']=nightsgnr['Value'].astype(int)

# %%
print('Nights spent at holiday accomondations in Greece for non-residents for the years 2016-2017-2018-2019')
plt.pie(nightsgnr['Value'],labels=nightsgnr['TIME'],autopct='%1.1f%%')
plt.legend(title = "Four Years:")
plt.show()
# Out:
# Nights spent at holiday accomondations in Greece for non-residents for the years 2016-2017-2018-2019

# %%
nightsbnr= df[  df["TIME"] >=2016 ]
nightsbnr= nightsbnr[ nightsbnr["TIME"] <=2019 ]
nightsbnr=nightsbnr.sort_values(by=['TIME'])
nightsbnr=nightsbnr.loc[nightsbnr['GEO'] == 'Belgium']
nightsbnr=nightsbnr.loc[nightsbnr['C_RESID'] == 'Foreign country']
nightsbnr=nightsbnr.loc[nightsbnr['UNIT']== 'Number']
indices=[18304,21304,24304,27304]
nightsbnr=nightsbnr.loc[indices]
nightsbnr
# Out:
#        TIME      GEO          C_RESID    UNIT  \
# 18304  2016  Belgium  Foreign country  Number
# 21304  2017  Belgium  Foreign country  Number
# 24304  2018  Belgium  Foreign country  Number
# 27304  2019  Belgium  Foreign country  Number
#
#                                                  NACE_R2      Value  \
# 18304  Camping grounds, recreational vehicle parks an...  1,604,510
# 21304  Camping grounds, recreational vehicle parks an...  1,615,654
# 24304  Camping grounds, recreational vehicle parks an...  1,921,589
# 27304  Camping grounds, recreational vehicle parks an...  1,853,403
#
#       Flag and Footnotes
# 18304                NaN
# 21304                NaN
# 24304                NaN
# 27304                NaN

# %%
nightsbnr['Value'] =nightsbnr['Value'].replace(',','', regex=True)
nightsbnr['Value']=nightsbnr['Value'].astype(int)

# %%
print('Nights spent at holiday accomondations in Belgium for non-residents the years 2016-2017-2018-2019')
plt.pie(nightsbnr['Value'],labels=nightsbnr['TIME'],autopct='%1.1f%%')
plt.legend(title = "Four Years:")
plt.show()
# Out:
# Nights spent at holiday accomondations in Belgium for non-residents the years 2016-2017-2018-2019

# %% [markdown]
# # Arrivals at tourist accommodation establishments
# Ακριβώς η ίδια διαδικασία με το κομμάτι των nights

# %%
df1=pd.read_csv("tour_occ_arnat_1_Data.csv")
df1
# Out:
#        TIME                                        GEO          C_RESID  \
# 0      2010  European Union - 27 countries (from 2020)  Foreign country
# 1      2010  European Union - 27 countries (from 2020)  Foreign country
# 2      2010  European Union - 27 countries (from 2020)  Foreign country
# 3      2010  European Union - 27 countries (from 2020)  Foreign country
# 4      2010  European Union - 27 countries (from 2020)  Foreign country
# ...     ...                                        ...              ...
# 11995  2019                                     Turkey            Total
# 11996  2019                                     Turkey            Total
# 11997  2019                                     Turkey            Total
# 11998  2019                                     Turkey            Total
# 11999  2019                                     Turkey            Total
#
#                                        UNIT  \
# 0                                    Number
# ...

# %%
arrivalsg= df1[  df1["TIME"] >=2016 ]
arrivalsg= arrivalsg[ arrivalsg["TIME"] <=2019 ]
arrivalsg=arrivalsg.sort_values(by=['TIME'])
arrivalsg=arrivalsg.loc[arrivalsg['GEO'] == 'Greece']
arrivalsg=arrivalsg.loc[arrivalsg['C_RESID'] == 'Total']
arrivalsg=arrivalsg.loc[arrivalsg['UNIT']== 'Number']

indices=[7550,8750,9950,11150]
arrivalsg=arrivalsg.loc[indices]

arrivalsg
# Out:
#        TIME     GEO C_RESID    UNIT  \
# 7550   2016  Greece   Total  Number
# 8750   2017  Greece   Total  Number
# 9950   2018  Greece   Total  Number
# 11150  2019  Greece   Total  Number
#
#                                                  NACE_R2       Value  \
# 7550   Hotels; holiday and other short-stay accommoda...  24,996,038
# 8750   Hotels; holiday and other short-stay accommoda...  27,211,268
# 9950   Hotels; holiday and other short-stay accommoda...  28,718,094
# 11150  Hotels; holiday and other short-stay accommoda...  34,202,053
#
#       Flag and Footnotes
# 7550                 NaN
# 8750                 NaN
# 9950                 NaN
# 11150                NaN

# %%
arrivalsg['Value'] =arrivalsg['Value'].replace(',','', regex=True)
arrivalsg['Value']=arrivalsg['Value'].astype(int)
arrivalsg['Value']
# Out:
# 7550     24996038
# 8750     27211268
# 9950     28718094
# 11150    34202053
# Name: Value, dtype: int32

# %%
print('Arrivals at tourist accommodation establishments in Greece for the years 2016-2017-2018-2019')
plt.pie(arrivalsg['Value'],labels=arrivalsg['TIME'],autopct='%1.1f%%')
plt.legend(title = "Four Years:")
plt.show()
# Out:
# Arrivals at tourist accommodation establishments in Greece for the years 2016-2017-2018-2019

# %%
arrivalsb= df1[  df1["TIME"] >=2016 ]
arrivalsb= arrivalsb[ arrivalsb["TIME"] <=2019 ]
arrivalsb=arrivalsb.sort_values(by=['TIME'])
arrivalsb=arrivalsb.loc[arrivalsb['GEO'] == 'Belgium']
arrivalsb=arrivalsb.loc[arrivalsb['C_RESID'] == 'Total']
arrivalsb=arrivalsb.loc[arrivalsb['UNIT']== 'Number']

indices=[7340,8540,9740,10940]
arrivalsb=arrivalsb.loc[indices]

arrivalsb
# Out:
#        TIME      GEO C_RESID    UNIT  \
# 7340   2016  Belgium   Total  Number
# 8540   2017  Belgium   Total  Number
# 9740   2018  Belgium   Total  Number
# 10940  2019  Belgium   Total  Number
#
#                                                  NACE_R2       Value  \
# 7340   Hotels; holiday and other short-stay accommoda...  15,210,781
# 8540   Hotels; holiday and other short-stay accommoda...  16,319,257
# 9740   Hotels; holiday and other short-stay accommoda...  17,559,915
# 10940  Hotels; holiday and other short-stay accommoda...  18,057,611
#
#       Flag and Footnotes
# 7340                 NaN
# 8540                 NaN
# 9740                 NaN
# 10940                NaN

# %%
arrivalsb['Value'] =arrivalsb['Value'].replace(',','', regex=True)
arrivalsb['Value']=arrivalsb['Value'].astype(int)
arrivalsb['Value']
# Out:
# 7340     15210781
# 8540     16319257
# 9740     17559915
# 10940    18057611
# Name: Value, dtype: int32

# %%
print('Arrivals at tourist accommodation establishments in Belgium for the years 2016-2017-2018-2019')
plt.pie(arrivalsb['Value'],labels=arrivalsb['TIME'],autopct='%1.1f%%')
plt.legend(title = "Four Years:")
plt.show()
# Out:
# Arrivals at tourist accommodation establishments in Belgium for the years 2016-2017-2018-2019

# %% [markdown]
# # Arrivals of non-residents at tourist accommodation establishments

# %%
arrivalsgnr= df1[  df1["TIME"] >=2016 ]
arrivalsgnr= arrivalsgnr[ arrivalsgnr["TIME"] <=2019 ]
arrivalsgnr=arrivalsgnr.sort_values(by=['TIME'])
arrivalsgnr=arrivalsgnr.loc[arrivalsgnr['GEO'] == 'Greece']
arrivalsgnr=arrivalsgnr.loc[arrivalsgnr['C_RESID'] == 'Foreign country']
arrivalsgnr=arrivalsgnr.loc[arrivalsgnr['UNIT']== 'Number']

indices=[7530,8730,9930,11130]
arrivalsgnr=arrivalsgnr.loc[indices]

arrivalsgnr
# Out:
#        TIME     GEO          C_RESID    UNIT  \
# 7530   2016  Greece  Foreign country  Number
# 8730   2017  Greece  Foreign country  Number
# 9930   2018  Greece  Foreign country  Number
# 11130  2019  Greece  Foreign country  Number
#
#                                                  NACE_R2       Value  \
# 7530   Hotels; holiday and other short-stay accommoda...  16,915,996
# 8730   Hotels; holiday and other short-stay accommoda...  19,068,697
# 9930   Hotels; holiday and other short-stay accommoda...  20,913,550
# 11130  Hotels; holiday and other short-stay accommoda...  25,038,498
#
#       Flag and Footnotes
# 7530                 NaN
# 8730                 NaN
# 9930                 NaN
# 11130                NaN

# %%
arrivalsgnr['Value'] =arrivalsgnr['Value'].replace(',','', regex=True)
arrivalsgnr['Value']=arrivalsgnr['Value'].astype(int)
arrivalsgnr['Value']
# Out:
# 7530     16915996
# 8730     19068697
# 9930     20913550
# 11130    25038498
# Name: Value, dtype: int32

# %%
print('Arrivals at tourist accommodation establishments of non-residents in Greece for the years 2016-2017-2018-2019')
plt.pie(arrivalsgnr['Value'],labels=arrivalsgnr['TIME'],autopct='%1.1f%%')
plt.legend(title = "Four Years:")
plt.show()
# Out:
# Arrivals at tourist accommodation establishments of non-residents in Greece for the years 2016-2017-2018-2019

# %%
arrivalsbnr= df1[  df1["TIME"] >=2016 ]
arrivalsbnr= arrivalsbnr[ arrivalsbnr["TIME"] <=2019 ]
arrivalsbnr=arrivalsbnr.sort_values(by=['TIME'])
arrivalsbnr=arrivalsbnr.loc[arrivalsbnr['GEO'] == 'Belgium']
arrivalsbnr=arrivalsbnr.loc[arrivalsbnr['C_RESID'] == 'Foreign country']
arrivalsbnr=arrivalsbnr.loc[arrivalsbnr['UNIT']== 'Number']

indices=[7320,8520,9720,10920]
arrivalsbnr=arrivalsbnr.loc[indices]

arrivalsbnr
# Out:
#        TIME      GEO          C_RESID    UNIT  \
# 7320   2016  Belgium  Foreign country  Number
# 8520   2017  Belgium  Foreign country  Number
# 9720   2018  Belgium  Foreign country  Number
# 10920  2019  Belgium  Foreign country  Number
#
#                                                  NACE_R2      Value  \
# 7320   Hotels; holiday and other short-stay accommoda...  7,481,422
# 8520   Hotels; holiday and other short-stay accommoda...  8,384,573
# 9720   Hotels; holiday and other short-stay accommoda...  9,118,854
# 10920  Hotels; holiday and other short-stay accommoda...  9,343,324
#
#       Flag and Footnotes
# 7320                 NaN
# 8520                 NaN
# 9720                 NaN
# 10920                NaN

# %%
arrivalsbnr['Value'] =arrivalsbnr['Value'].replace(',','', regex=True)
arrivalsbnr['Value']=arrivalsbnr['Value'].astype(int)
arrivalsbnr['Value']
# Out:
# 7320     7481422
# 8520     8384573
# 9720     9118854
# 10920    9343324
# Name: Value, dtype: int32

# %%
print('Arrivals at tourist accommodation establishments of non-residents in Belgium for the years 2016-2017-2018-2019')
plt.pie(arrivalsbnr['Value'],labels=arrivalsbnr['TIME'],autopct='%1.1f%%')
plt.legend(title = "Four Years:")
plt.show()
# Out:
# Arrivals at tourist accommodation establishments of non-residents in Belgium for the years 2016-2017-2018-2019

# %% [markdown]
# # Δημιουργία βάσης , πινάκων και εισαγωγή των στοιχείων

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password=""
)

mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE eurostattourism")

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database='eurostattourism' 
)

# %%
mycursor = mydb.cursor()
mycursor.execute("CREATE TABLE nights (id INT AUTO_INCREMENT PRIMARY KEY,country VARCHAR(255), year INT(4),touristsorigin VARCHAR(255),numberofnights INT(20))")

# %%
mycursor = mydb.cursor()
sql = "INSERT INTO nights (country,year,touristsorigin,numberofnights) VALUES (%s, %s, %s, %s)"
val = [
  ('Greece', '2016','Total','110020042'),
  ('Greece', '2017','Total','119009014'),
  ('Greece', '2018','Total','123087178' ),
  ('Greece', '2019','Total','143594467'),
  ('Greece', '2016','Foreign country','87912850'),
  ('Greece', '2017','Foreign country','97034421'),
  ('Greece', '2018','Foreign country','102571241' ),
  ('Greece', '2019','Foreign country','119971390'),
  ('Belgium', '2016','Total','36855214'),
  ('Belgium', '2017','Total','38677308'),
  ('Belgium', '2018','Total','41320284' ),
  ('Belgium', '2019','Total','42512847'),
  ('Belgium', '2016','Foreign country','1604510'),
  ('Belgium', '2017','Foreign country','1615654'),
  ('Belgium', '2018','Foreign country','1921589' ),
  ('Belgium', '2019','Foreign country','1853403')
]

mycursor.executemany(sql, val)
mydb.commit()

# %%
mycursor = mydb.cursor()
mycursor.execute("CREATE TABLE arrivals (ida INT AUTO_INCREMENT PRIMARY KEY,country VARCHAR(255), year INT(4),touristsorigin VARCHAR(255),numberofarrivals INT(20))")

# %%
mycursor = mydb.cursor()
sql = "INSERT INTO arrivals (country,year,touristsorigin,numberofarrivals) VALUES (%s, %s, %s, %s)"
val = [
  ('Greece', '2016','Total','24996038'),
  ('Greece', '2017','Total','27211268'),
  ('Greece', '2018','Total','28718094' ),
  ('Greece', '2019','Total','34202053'),
  ('Greece', '2016','Foreign country','16915996'),
  ('Greece', '2017','Foreign country','19068697'),
  ('Greece', '2018','Foreign country','20913550' ),
  ('Greece', '2019','Foreign country',' 25038498'),
  ('Belgium', '2016','Total','15210781'),
  ('Belgium', '2017','Total','16319257'),
  ('Belgium', '2018','Total','17559915' ),
  ('Belgium', '2019','Total','18057611'),
  ('Belgium', '2016','Foreign country','7481422'),
  ('Belgium', '2017','Foreign country','8384573'),
  ('Belgium', '2018','Foreign country','9118854' ),
  ('Belgium', '2019','Foreign country','9343324')
]

mycursor.executemany(sql, val)
mydb.commit()

# %%
mycursor = mydb.cursor()

mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)
# Out:
# ('arrivals',)
# ('nights',)

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM nights")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# (1, 'Greece', 2016, 'Total', 110020042)
# (2, 'Greece', 2017, 'Total', 119009014)
# (3, 'Greece', 2018, 'Total', 123087178)
# (4, 'Greece', 2019, 'Total', 143594467)
# (5, 'Greece', 2016, 'Foreign country', 87912850)
# (6, 'Greece', 2017, 'Foreign country', 97034421)
# (7, 'Greece', 2018, 'Foreign country', 102571241)
# (8, 'Greece', 2019, 'Foreign country', 119971390)
# (9, 'Belgium', 2016, 'Total', 36855214)
# (10, 'Belgium', 2017, 'Total', 38677308)
# (11, 'Belgium', 2018, 'Total', 41320284)
# (12, 'Belgium', 2019, 'Total', 42512847)
# (13, 'Belgium', 2016, 'Foreign country', 1604510)
# (14, 'Belgium', 2017, 'Foreign country', 1615654)
# (15, 'Belgium', 2018, 'Foreign country', 1921589)
# (16, 'Belgium', 2019, 'Foreign country', 1853403)

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM arrivals")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# (1, 'Greece', 2016, 'Total', 24996038)
# (2, 'Greece', 2017, 'Total', 27211268)
# (3, 'Greece', 2018, 'Total', 28718094)
# (4, 'Greece', 2019, 'Total', 34202053)
# (5, 'Greece', 2016, 'Foreign country', 16915996)
# (6, 'Greece', 2017, 'Foreign country', 19068697)
# (7, 'Greece', 2018, 'Foreign country', 20913550)
# (8, 'Greece', 2019, 'Foreign country', 25038498)
# (9, 'Belgium', 2016, 'Total', 15210781)
# (10, 'Belgium', 2017, 'Total', 16319257)
# (11, 'Belgium', 2018, 'Total', 17559915)
# (12, 'Belgium', 2019, 'Total', 18057611)
# (13, 'Belgium', 2016, 'Foreign country', 7481422)
# (14, 'Belgium', 2017, 'Foreign country', 8384573)
# (15, 'Belgium', 2018, 'Foreign country', 9118854)
# (16, 'Belgium', 2019, 'Foreign country', 9343324)

# %% [markdown]
# # Διαγραφή βάσης για να την δημιουργήσω ξανά την ώρα της εξέτασης

# %%
mycursor = mydb.cursor()

sql = "DROP DATABASE eurostattourism"

mycursor.execute(sql)

# %% [markdown]
# # Export data as a csv

# %%
sql_query = pd.read_sql_query('select * from nights',mydb) 
df = pd.DataFrame(sql_query)
df.to_csv (r'C:\Users\user\Desktop\6ο εξαμηνο\αρχες python\mydatanights.csv', index = False)

# %%
sql_query = pd.read_sql_query('select * from nights',mydb) 
df = pd.DataFrame(sql_query)
df.to_csv (r'C:\Users\user\Desktop\6ο εξαμηνο\αρχες python\mydataarrival.csv', index = False)

# %% [markdown]
# # Ένα απλό GUI για πιο εύκολη περιήγηση στα δεδομένα μας

# %%
import tkinter as tk
from tkinter import *

# %%
#-------------------------------------------------------------------------------------------------------------------------------
#Gui for Greece
#-------------------------------------------------------------------------------------------------------------------------------
def greece():
    global greece_screen

    greece_screen=Toplevel(root)
    greece_screen.title("Greece")
    greece_screen.geometry("300x300")
    greece_screen['background']='#9C94A7'

    Button(greece_screen,text="Nights spent at holiday accommondations",command=see_nights,bg='#D1BFE9', height="2", width="50").pack() 
    Button(greece_screen,text="Nights spent by non-residents ",bg='#D1BFE9',height="2",command=see_nightsnr, width="50").pack()    
    Button(greece_screen,text="Arrivals at tourist accommodation establishments",command=see_arrivals,bg='#D1BFE9', height="2", width=" 50").pack()
    Button(greece_screen,text="Arrivals of non-residents ",command=see_arrivalsnr,bg='#D1BFE9', height="2", width="50").pack()
   
def see_nights():
    global nights_screen
    nights_screen=Toplevel(greece_screen)
    nights_screen.title("Greece's data")
    nights_screen.geometry("400x300")
    nights_screen['background']='#9C94A7'
    db = mysql.connector.connect(host ="localhost",
                                    user = "root",
                                    password = "",
                                    db ='eurostattourism' )
 
    cursor = db.cursor()
    sql="SELECT* FROM nights WHERE country='Greece' and touristsorigin='Total'"
    cursor.execute(sql)
    myresult = cursor.fetchall()
    
   


    e=Label(nights_screen,width=10,text='Id',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=0)
    e=Label(nights_screen,width=10,text='Coutry',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=1)
    e=Label(nights_screen,width=10,text='Year',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=2)
    e=Label(nights_screen,width=10,text='Origin',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=3)
    e=Label(nights_screen,width=10,text='Value',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=4)


    i=1
    for nights in myresult: 
        for j in range(len(nights)):
            e = Entry(nights_screen, width=10,bg='#D1BFE9') 
            e.grid(row=i, column=j) 
            e.insert(END, nights[j])
        i=i+1 
        
def see_nightsnr():
    global nightsnr_screen
    nightsnr_screen=Toplevel(greece_screen)
    nightsnr_screen.title("Greece's data")
    nightsnr_screen.geometry("400x300")
    nightsnr_screen['background']='#9C94A7'
    db = mysql.connector.connect(host ="localhost",
                                    user = "root",
                                    password = "",
                                    db ='eurostattourism' )
 
    cursor = db.cursor()
    sql="SELECT* FROM nights WHERE country='Greece' and touristsorigin='Foreign country'"
    cursor.execute(sql)
    myresult = cursor.fetchall()
    
    
    e=Label(nightsnr_screen,width=10,text='Id',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=0)
    e=Label(nightsnr_screen,width=10,text='Coutry',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=1)
    e=Label(nightsnr_screen,width=10,text='Year',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=2)
    e=Label(nightsnr_screen,width=10,text='Origin',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=3)
    e=Label(nightsnr_screen,width=10,text='Value',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=4)


    i=1
    for nights in myresult: 
        for j in range(len(nights)):
            e = Entry(nightsnr_screen, width=10,bg='#D1BFE9') 
            e.grid(row=i, column=j) 
            e.insert(END, nights[j])
        i=i+1 
    
def see_arrivals():
    global arrivals_screen
    arrivals_screen=Toplevel(greece_screen)
    arrivals_screen.title("Greece's data")
    arrivals_screen.geometry("400x300")
    arrivals_screen['background']='#9C94A7'
    db = mysql.connector.connect(host ="localhost",
                                    user = "root",
                                    password = "",
                                    db ='eurostattourism' )
 
    cursor = db.cursor()
    sql="SELECT * FROM arrivals WHERE country='Greece' and touristsorigin='Total'"
    cursor.execute(sql)
    myresult = cursor.fetchall()
    
    
    e=Label(arrivals_screen,width=10,text='Id',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=0)
    e=Label(arrivals_screen,width=10,text='Coutry',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=1)
    e=Label(arrivals_screen,width=10,text='Year',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=2)
    e=Label(arrivals_screen,width=10,text='Origin',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=3)
    e=Label(arrivals_screen,width=10,text='Value',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=4)


    i=1
    for arrivals in myresult: 
        for j in range(len(arrivals)):
            e = Entry(arrivals_screen, width=10,bg='#D1BFE9') 
            e.grid(row=i, column=j) 
            e.insert(END, arrivals[j])
        i=i+1 
    
    
def see_arrivalsnr():
    global arrivalsnr_screen
    arrivalsnr_screen=Toplevel(greece_screen)
    arrivalsnr_screen.title("Greece's data")
    arrivalsnr_screen.geometry("400x300")
    arrivalsnr_screen['background']='#9C94A7'
    db = mysql.connector.connect(host ="localhost",
                                    user = "root",
                                    password = "",
                                    db ='eurostattourism' )
 
    cursor = db.cursor()
    sql="SELECT* FROM arrivals WHERE country='Greece' and touristsorigin='Foreign country'"
    cursor.execute(sql)
    myresult = cursor.fetchall()
    
    
    e=Label(arrivalsnr_screen,width=10,text='Id',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=0)
    e=Label(arrivalsnr_screen,width=10,text='Coutry',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=1)
    e=Label(arrivalsnr_screen,width=10,text='Year',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=2)
    e=Label(arrivalsnr_screen,width=10,text='Origin',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=3)
    e=Label(arrivalsnr_screen,width=10,text='Value',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=4)


    i=1
    for arrivals in myresult: 
        for j in range(len(arrivals)):
            e = Entry(arrivalsnr_screen, width=10,bg='#D1BFE9') 
            e.grid(row=i, column=j) 
            e.insert(END, arrivals[j])
        i=i+1 
    
     
#-------------------------------------------------------------------------------------------------------------------------------    
#Gui for Belgium    
#-------------------------------------------------------------------------------------------------------------------------------

def belgium():
    global belgium_screen

    belgium_screen=Toplevel(root)
    belgium_screen.title("Belgium")
    belgium_screen.geometry("300x300")
    belgium_screen['background']='#9C94A7'

    Button(belgium_screen,text="Nights spent at holiday accomondations",command=see_nightsb,bg='#D1BFE9', height="2", width="50").pack() 
    Button(belgium_screen,text="Nights spent by non-residents ",command=see_nightsnrb,bg='#D1BFE9',height="2", width="50").pack()    
    Button(belgium_screen,text="Arrivals at tourist accommodation establishments",command=see_arrivalsb,bg='#D1BFE9', height="2", width=" 50").pack()
    Button(belgium_screen,text="Arrivals of non-residents ",command=see_arrivalsnrb,bg='#D1BFE9', height="2", width="50").pack()
       


def see_nightsb():
    global nightsb_screen
    nightsb_screen=Toplevel(belgium_screen)
    nightsb_screen.title("Belgium's data")
    nightsb_screen.geometry("400x300")
    nightsb_screen['background']='#9C94A7'
    db = mysql.connector.connect(host ="localhost",
                                    user = "root",
                                    password = "",
                                    db ='eurostattourism' )
 
    cursor = db.cursor()
    sql="SELECT* FROM nights WHERE country='Belgium' and touristsorigin='Total'"
    cursor.execute(sql)
    myresult = cursor.fetchall()
    
    
    e=Label(nightsb_screen,width=10,text='Id',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=0)
    e=Label(nightsb_screen,width=10,text='Coutry',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=1)
    e=Label(nightsb_screen,width=10,text='Year',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=2)
    e=Label(nightsb_screen,width=10,text='Origin',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=3)
    e=Label(nightsb_screen,width=10,text='Value',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=4)


    i=1
    for nights in myresult: 
        for j in range(len(nights)):
            e = Entry(nightsb_screen, width=10,bg='#D1BFE9') 
            e.grid(row=i, column=j) 
            e.insert(END, nights[j])
        i=i+1  

  
    
def see_nightsnrb():
    global nightsnrb_screen
    nightsnrb_screen=Toplevel(belgium_screen)
    nightsnrb_screen.title("Belgium's data")
    nightsnrb_screen.geometry("400x300")
    nightsnrb_screen['background']='#9C94A7'
    db = mysql.connector.connect(host ="localhost",
                                    user = "root",
                                    password = "",
                                    db ='eurostattourism' )
 
    cursor = db.cursor()
    sql="SELECT* FROM nights WHERE country='Belgium' and touristsorigin='Foreign country'"
    cursor.execute(sql)
    myresult = cursor.fetchall()
    
    e=Label(nightsnrb_screen,width=10,text='Id',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=0)
    e=Label(nightsnrb_screen,width=10,text='Coutry',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=1)
    e=Label(nightsnrb_screen,width=10,text='Year',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=2)
    e=Label(nightsnrb_screen,width=10,text='Origin',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=3)
    e=Label(nightsnrb_screen,width=10,text='Value',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=4)


    i=1
    for nights in myresult: 
        for j in range(len(nights)):
            e = Entry(nightsnrb_screen, width=10,bg='#D1BFE9') 
            e.grid(row=i, column=j) 
            e.insert(END, nights[j])
        i=i+1     

    
def see_arrivalsb():
    global arrivalsb_screen
    arrivalsb_screen=Toplevel(belgium_screen)
    arrivalsb_screen.title("Belgium's data")
    arrivalsb_screen.geometry("400x300")
    arrivalsb_screen['background']='#9C94A7'
    db = mysql.connector.connect(host ="localhost",
                                    user = "root",
                                    password = "",
                                    db ='eurostattourism' )
 
    cursor = db.cursor()
    sql="SELECT * FROM arrivals WHERE country='Belgium' and touristsorigin='Total'"
    cursor.execute(sql)
    myresult = cursor.fetchall()
    
    e=Label(arrivalsb_screen,width=10,text='Id',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=0)
    e=Label(arrivalsb_screen,width=10,text='Coutry',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=1)
    e=Label(arrivalsb_screen,width=10,text='Year',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=2)
    e=Label(arrivalsb_screen,width=10,text='Origin',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=3)
    e=Label(arrivalsb_screen,width=10,text='Value',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=4)


    i=1
    for arrivals in myresult: 
        for j in range(len(arrivals)):
            e = Entry(arrivalsb_screen, width=10,bg='#D1BFE9') 
            e.grid(row=i, column=j) 
            e.insert(END, arrivals[j])
        i=i+1 
    
    
def see_arrivalsnrb():
    global arrivalsnrb_screen
    arrivalsnrb_screen=Toplevel(belgium_screen)
    arrivalsnrb_screen.title("Belgium's data")
    arrivalsnrb_screen.geometry("400x300")
    arrivalsnrb_screen['background']='#9C94A7'
    db = mysql.connector.connect(host ="localhost",
                                    user = "root",
                                    password = "",
                                    db ='eurostattourism' )
 
    cursor = db.cursor()
    sql="SELECT* FROM arrivals WHERE country='Belgium' and touristsorigin='Foreign country'"
    cursor.execute(sql)
    myresult = cursor.fetchall()
    
    
    e=Label(arrivalsnrb_screen,width=10,text='Id',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=0)
    e=Label(arrivalsnrb_screen,width=10,text='Coutry',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=1)
    e=Label(arrivalsnrb_screen,width=10,text='Year',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=2)
    e=Label(arrivalsnrb_screen,width=10,text='Origin',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=3)
    e=Label(arrivalsnrb_screen,width=10,text='Value',borderwidth=2, relief='ridge',anchor='w',bg='#D1BFE9')
    e.grid(row=0,column=4)


    i=1
    for arrivals in myresult: 
        for j in range(len(arrivals)):
            e = Entry(arrivalsnrb_screen, width=10,bg='#D1BFE9') 
            e.grid(row=i, column=j) 
            e.insert(END, arrivals[j])
        i=i+1 
#-------------------------------------------------------------------------------------------------------------------------------    
#main screen        
#-------------------------------------------------------------------------------------------------------------------------------       
root = Tk()
root.geometry("300x300")
root.title("Welcome")
root['background']='#9C94A7'

db = mysql.connector.connect(host ="localhost",
                                     user = "root",
                                     password = "",
                                     db ='eurostattourism')
    



a=Label(root, text ="Tourism in Greece and Belgium for the years 2016-2019",bg='#D1BFE9')
a.place(x = 4, y = 25)
 
b=Button(root,text="Belgium", height="2", width="30",bg='#D1BFE9',command=belgium)
c=Button(root,text="Greece", height="2", width="30",bg='#D1BFE9',command=greece)

b.place(x =35 , y= 50)
c.place(x =35 , y= 110)

root.mainloop()
